# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
airquality = pd.read_csv('airquality.csv')
airquality.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5

# %%
airquality[airquality.columns[:4]].plot.box()
# Out:
# <Axes: >

# %%
scaler = MinMaxScaler()

# %%
transformed = scaler.fit_transform(airquality[airquality.columns[:4]])

# %%
transformed
# Out:
# array([[0.23952096, 0.55963303, 0.3       , 0.26829268],
#        [0.20958084, 0.33944954, 0.33157895, 0.3902439 ],
#        [0.06586826, 0.43425076, 0.57368421, 0.43902439],
#        [0.10179641, 0.93577982, 0.51578947, 0.14634146],
#        [       nan,        nan, 0.66315789, 0.        ],
#        [0.16167665,        nan, 0.69473684, 0.24390244],
#        [0.13173653, 0.89296636, 0.36315789, 0.2195122 ],
#        [0.10778443, 0.28134557, 0.63684211, 0.07317073],
#        [0.04191617, 0.03669725, 0.96842105, 0.12195122],
#        [       nan, 0.57186544, 0.36315789, 0.31707317],
#        [0.03592814,        nan, 0.27368421, 0.43902439],
#        [0.08982036, 0.76146789, 0.42105263, 0.31707317],
#        [0.05988024, 0.86544343, 0.39473684, 0.24390244],
#        [0.07784431, 0.81651376, 0.48421053, 0.29268293],
#        [0.10179641, 0.17737003, 0.60526316, 0.04878049],
#        [0.07784431, 1.        , 0.51578947, 0.19512195],
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard = StandardScaler()

# %%
transformed = standard.fit_transform(airquality[airquality.columns[:4]])

# %%
transformed
# Out:
# array([[-3.43826159e-02,  4.53316662e-02, -7.28332230e-01,
#         -1.15348973e+00],
#        [-1.86610992e-01, -7.56901456e-01, -5.57463590e-01,
#         -6.23507964e-01],
#        [-9.17307195e-01, -4.11495529e-01,  7.52529314e-01,
#         -4.11515256e-01],
#        [-7.34633144e-01,  1.41581325e+00,  4.39270141e-01,
#         -1.68347150e+00],
#        [            nan,             nan,  1.23665713e+00,
#         -2.31944963e+00],
#        [-4.30176393e-01,             nan,  1.40752577e+00,
#         -1.25948609e+00],
#        [-5.82404768e-01,  1.25982348e+00, -3.86594951e-01,
#         -1.36548244e+00],
#        [-7.04187469e-01, -9.68601864e-01,  1.09426659e+00,
#         -2.00146056e+00],
#        [-1.03908990e+00, -1.85997200e+00,  2.88838731e+00,
#         -1.78946786e+00],
#        [            nan,  8.99001730e-02, -3.86594951e-01,
#         -9.41497026e-01],
#        [-1.06953557e+00,             nan, -8.70722763e-01,
#         -4.11515256e-01],
# ...
